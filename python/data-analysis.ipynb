# %%
import json
from datetime import datetime
import pandas as pd
import numpy as np
from pprint import pprint

# %%
df = pd.read_csv('./data/cleaned-data.csv')

df.head()
# Out:
#   condition  year  mileage transmission fuel_type       engine    body_type  \
# 0      Used  2019    51900    Automatic  Gasoline  3.6L Gas V6        Sedan
# 1      Used  2016    78000    Automatic  Gasoline  5.7L Gas V8          SUV
# 2      Used  2018    42900    Automatic  Gasoline  3.0L Gas V6  Convertible
# 3      Used  2017    29000    Automatic  Gasoline  2.5L Gas I4        Sedan
# 4      Used  2016    63300    Automatic  Gasoline  5.0L Gas V8        Sedan
#
#        make drive_type         model                         vehicle_title  \
# 0  Cadillac        AWD           CT6  Rebuilt, Rebuildable & Reconstructed
# 1    Toyota        4WD  Land Cruiser                                 Clean
# 2    Jaguar        AWD        F-Type                               Salvage
# 3    Nissan        FWD        Altima  Rebuilt, Rebuildable & Reconstructed
# 4   Hyundai        RWD         Equus  Rebuilt, Rebuildable & Reconstructed
#
# ...

# %%
occ = df['year'].value_counts()
occ.plot.pie(y='year', labels=occ.index, autopct='%.2f')
# Out:
# <Axes: ylabel='year'>
