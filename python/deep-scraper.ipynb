# %%
import json
from bs4 import BeautifulSoup as soup
from splinter import Browser
from pprint import pprint
import time

f = open('data/vehicles.json')

data = json.load(f)

pprint(data[0])

f.close()
# Out:
# {'item_url': 'https://www.ebay.com/itm/185913370660?hash=item2b494ce824:g:UGQAAOSwGn5j~pIv',
#  'price': '$1.30',
#  'sold_date': 'SOLD  May 25, 2023',
#  'title': '2019 Cadillac CT6 PREMIUM LUXURY'}

# %%
browser=Browser('chrome')

# %%
def ScrapePage(page):
    labels = page.find_all(class_="ux-labels-values__labels-content")
    values = page.find_all(class_="ux-labels-values__values-content")

    item = {}

    condition = year = mileage = interior_color = transmission = fuel_consumption_rate = fuel_type = horse_power = ""
    engine_size = exterior_color = number_of_doors = engine = body_type = number_of_cylinders = make = drive_type = ""
    model = country_of_manufacture = vehicle_title = ""

    for i, element in enumerate(labels):
        
        match element.text:
            case "Condition":
                condition = values[i].text
            case "Year":
                year = values[i].text
            case "Mileage":
                mileage = values[i].text
            case "Interior Color":
                interior_color = values[i].text
            case "Transmission":
                transmission = values[i].text
            case "Fuel Consumption Rate":
                fuel_consumption_rate = values[i].text
            case "Fuel Type":
                fuel_type = values[i].text
            case "Horse Power":
                horse_power = values[i].text
            case "Engine Size":
                engine_size = values[i].text
            case "Exterior Color":
                exterior_color = values[i].text
            case "Number of Doors":
                number_of_doors = values[i].text
            case "Engine":
                engine = values[i].text
            case "Body Type":
                body_type = values[i].text
            case "Number of Cylinders":
                number_of_cylinders = values[i].text
            case "Make":
                make = values[i].text
            case "Drive Type":
                drive_type = values[i].text
            case "Model":
                model = values[i].text
            case "Country/Region of Manufacture":
                country_of_manufacture = values[i].text
            case "Vehicle Title":
                vehicle_title = values[i].text

    item = {
        "condition" : condition,
        "year" : year,
        "mileage" : mileage,
        "interior_color" : interior_color,
        "transmission" : transmission,
        "fuel_consumption_rate" : fuel_consumption_rate,
        "fuel_type" : fuel_type,
        "horse_power" : horse_power,
        "engine_size" : engine_size,
        "exterior_color" : exterior_color,
        "number_of_doors" : number_of_doors,
        "engine" : engine,
        "body_type" : body_type,
        "number_of_cylinders" : number_of_cylinders,
        "make" : make,
        "drive_type" : drive_type,
        "model" : model,
        "country_of_manufacture" : country_of_manufacture,
        "vehicle_title" : vehicle_title
    }        
    return item

# %%
myItems = []



for l in data:
    browser.visit(l['item_url'])
    
    html = browser.html
    mySoup = soup(html, 'html.parser')
    
    myItems.append(ScrapePage(mySoup))
    
    time.sleep(5)
    
pprint(myItems)
# Out:
# [{'body_type': 'Sedan',
#   'condition': 'Used',
#   'country_of_manufacture': 'United States',
#   'drive_type': 'AWD',
#   'engine': '3.6L Gas V6',
#   'engine_size': '3.6 L',
#   'exterior_color': 'Black',
#   'fuel_consumption_rate': 'City 18/Hwy 27/Comb 21 MPG',
#   'fuel_type': 'Gasoline',
#   'horse_power': '335',
#   'interior_color': 'Black',
#   'make': 'Cadillac',
#   'mileage': '51900',
#   'model': 'CT6',
#   'number_of_cylinders': '6',
#   'number_of_doors': '4',
#   'transmission': 'Automatic',
#   'vehicle_title': 'Rebuilt, Rebuildable & Reconstructed',
#   'year': '2019'},
#  {'body_type': 'Coupe',
#   'condition': 'Used: A vehicle is considered used if it has been registered '
#                'and issued a title. Used vehicles have ...  Read moreabout the '
#                'conditionUsed: A vehicle is considered used if it has been '
#                'registered and issued a title. Used vehicles have had at least '
#                'one previous owner. The condition of the exterior, interior '
#                "and engine can vary depending on the vehicle's history. See "
#                "the seller's listing for full details and description of any "
#                'imperfections. See all condition definitionsopens in a new '
#                'window or tab ',
#   'country_of_manufacture': 'United Kingdom',
#   'drive_type': '2WD',
#   'engine': '',
#   'engine_size': '',
#   'exterior_color': 'Aqua',
#   'fuel_consumption_rate': '',
#   'fuel_type': 'Gasoline',
#   'horse_power': '',
#   'interior_color': 'Tan',
#   'make': 'Lotus',
#   'mileage': '52000',
#   'model': 'Evora',
#   'number_of_cylinders': '6',
#   'number_of_doors': '2',
#   'transmission': 'Manual',
#   'vehicle_title': 'Clean',
#   'year': '2010'},
#  {'body_type': 'SUV',
#   'condition': 'Used',
#   'country_of_manufacture': 'Japan',
#   'drive_type': '4WD',
#   'engine': '5.7L Gas V8',
#   'engine_size': '5.7 L',
#   'exterior_color': 'Gray',
#   'fuel_consumption_rate': '',
#   'fuel_type': 'Gasoline',
#   'horse_power': '',
#   'interior_color': 'Black',
#   'make': 'Toyota',
#   'mileage': '78000',
#   'model': 'Land Cruiser',
#   'number_of_cylinders': '8',
#   'number_of_doors': '5',
#   'transmission': 'Automatic',
#   'vehicle_title': 'Clean',
#   'year': '2016'}]

# %%
browser.quit()
